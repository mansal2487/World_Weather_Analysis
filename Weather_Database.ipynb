# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 803

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | smithers
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | carauari
# Processing Record 5 of Set 1 | la rioja
# Processing Record 6 of Set 1 | agustin codazzi
# Processing Record 7 of Set 1 | ibirite
# Processing Record 8 of Set 1 | baykit
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | lardos
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | ihosy
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | pangoa
# Processing Record 15 of Set 1 | staryy nadym
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | plettenberg bay
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | te anau
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | sherkot
# Processing Record 25 of Set 1 | yar-sale
# Processing Record 26 of Set 1 | salalah
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | galesong
# Processing Record 29 of Set 1 | awjilah
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | mehamn
# Processing Record 33 of Set 1 | najran
# Processing Record 34 of Set 1 | amboasary
# Processing Record 35 of Set 1 | carutapera
# Processing Record 36 of Set 1 | awbari
# Processing Record 37 of Set 1 | silvan
# Processing Record 38 of Set 1 | manggar
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | nuuk
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | severo-kurilsk
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | ambovombe
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | norman wells
# Processing Record 2 of Set 2 | mumford
# Processing Record 3 of Set 2 | hongjiang
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | kutum
# Processing Record 6 of Set 2 | margate
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | ketchikan
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | bolshevik
# Processing Record 11 of Set 2 | sitka
# Processing Record 12 of Set 2 | licheng
# Processing Record 13 of Set 2 | yatou
# Processing Record 14 of Set 2 | sechura
# Processing Record 15 of Set 2 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 16 of Set 2 | russell
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | sibu
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | hofn
# Processing Record 26 of Set 2 | goundam
# Processing Record 27 of Set 2 | roald
# Processing Record 28 of Set 2 | varzea da palma
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | inirida
# Processing Record 32 of Set 2 | korop
# Processing Record 33 of Set 2 | lorengau
# Processing Record 34 of Set 2 | bumba
# Processing Record 35 of Set 2 | loreto
# Processing Record 36 of Set 2 | ravar
# Processing Record 37 of Set 2 | lembeni
# Processing Record 38 of Set 2 | iwaki
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | portland
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | tura
# Processing Record 45 of Set 2 | ninghai
# Processing Record 46 of Set 2 | cidreira
# Processing Record 47 of Set 2 | tambura
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | pisco
# Processing Record 50 of Set 2 | bria
# Processing Record 1 of Set 3 | coahuayana
# Processing Record 2 of Set 3 | sorland
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | zaysan
# Processing Record 5 of Set 3 | sistranda
# Processing Record 6 of Set 3 | saskylakh
# Processing Record 7 of Set 3 | taoudenni
# Processing Record 8 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 3 | touros
# Processing Record 10 of Set 3 | cabo san lucas
# Processing Record 11 of Set 3 | san quintin
# Processing Record 12 of Set 3 | olenegorsk
# Processing Record 13 of Set 3 | laguna
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | coachella
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 3 | sao joao da barra
# Processing Record 18 of Set 3 | pangai
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | maues
# Processing Record 21 of Set 3 | vostok
# Processing Record 22 of Set 3 | wattegama
# Processing Record 23 of Set 3 | rameswaram
# Processing Record 24 of Set 3 | zyryanka
# Processing Record 25 of Set 3 | iztapa
# Processing Record 26 of Set 3 | belaya gora
# Processing Record 27 of Set 3 | san cristobal
# Processing Record 28 of Set 3 | celestun
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | tatvan
# Processing Record 32 of Set 3 | jumla
# Processing Record 33 of Set 3 | abu dhabi
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | kimbe
# Processing Record 36 of Set 3 | morros
# Processing Record 37 of Set 3 | hiroshima
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | tommot
# Processing Record 40 of Set 3 | pangnirtung
# Processing Record 41 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 3 | martapura
# Processing Record 43 of Set 3 | normandin
# Processing Record 44 of Set 3 | sao filipe
# Processing Record 45 of Set 3 | pasni
# Processing Record 46 of Set 3 | isangel
# Processing Record 47 of Set 3 | atbasar
# Processing Record 48 of Set 3 | alofi
# Processing Record 49 of Set 3 | puro
# Processing Record 50 of Set 3 | tuktoyaktuk
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | lubango
# Processing Record 3 of Set 4 | varhaug
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | havoysund
# Processing Record 6 of Set 4 | mareeba
# Processing Record 7 of Set 4 | grindavik
# Processing Record 8 of Set 4 | berlevag
# Processing Record 9 of Set 4 | johi
# Processing Record 10 of Set 4 | chapais
# Processing Record 11 of Set 4 | suntar
# Processing Record 12 of Set 4 | bethel
# Processing Record 13 of Set 4 | udachnyy
# Processing Record 14 of Set 4 | ostrovnoy
# Processing Record 15 of Set 4 | barmer
# Processing Record 16 of Set 4 | asosa
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | port blair
# Processing Record 19 of Set 4 | constitucion
# Processing Record 20 of Set 4 | portsmouth
# Processing Record 21 of Set 4 | narsaq
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | esil
# Processing Record 24 of Set 4 | guicheng
# City not found. Skipping...
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | los llanos de aridane
# Processing Record 27 of Set 4 | tarata
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | hokitika
# Processing Record 30 of Set 4 | muros
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | bitung
# Processing Record 33 of Set 4 | arvika
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | heide
# Processing Record 36 of Set 4 | ixtapa
# Processing Record 37 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | iqaluit
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | fairview
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | havre-saint-pierre
# Processing Record 44 of Set 4 | castro
# Processing Record 45 of Set 4 | upington
# Processing Record 46 of Set 4 | marion
# Processing Record 47 of Set 4 | chuy
# Processing Record 48 of Set 4 | karpathos
# Processing Record 49 of Set 4 | tabuk
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | tsiroanomandidy
# Processing Record 2 of Set 5 | clyde river
# Processing Record 3 of Set 5 | manyoni
# Processing Record 4 of Set 5 | santa rita
# Processing Record 5 of Set 5 | port shepstone
# Processing Record 6 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 5 | imbituba
# Processing Record 8 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 5 | daigo
# Processing Record 10 of Set 5 | kalmunai
# Processing Record 11 of Set 5 | lavrentiya
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | arraial do cabo
# Processing Record 14 of Set 5 | kaka
# Processing Record 15 of Set 5 | geraldton
# Processing Record 16 of Set 5 | nova borova
# Processing Record 17 of Set 5 | daloa
# Processing Record 18 of Set 5 | titel
# Processing Record 19 of Set 5 | perry
# Processing Record 20 of Set 5 | nioki
# Processing Record 21 of Set 5 | provideniya
# Processing Record 22 of Set 5 | puerto ayora
# Processing Record 23 of Set 5 | mahebourg
# Processing Record 24 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 5 | coquimbo
# Processing Record 26 of Set 5 | den helder
# Processing Record 27 of Set 5 | porbandar
# Processing Record 28 of Set 5 | umm kaddadah
# Processing Record 29 of Set 5 | handan
# Processing Record 30 of Set 5 | solwezi
# Processing Record 31 of Set 5 | guaruja
# Processing Record 32 of Set 5 | ismailia
# Processing Record 33 of Set 5 | amga
# Processing Record 34 of Set 5 | natal
# Processing Record 35 of Set 5 | raudeberg
# Processing Record 36 of Set 5 | shimoda
# Processing Record 37 of Set 5 | sur
# Processing Record 38 of Set 5 | valparaiso
# Processing Record 39 of Set 5 | baruun-urt
# Processing Record 40 of Set 5 | barrow
# Processing Record 41 of Set 5 | lerwick
# Processing Record 42 of Set 5 | mirnyy
# Processing Record 43 of Set 5 | vardo
# Processing Record 44 of Set 5 | guadalajara
# Processing Record 45 of Set 5 | monte carmelo
# Processing Record 46 of Set 5 | micheweni
# Processing Record 47 of Set 5 | japura
# Processing Record 48 of Set 5 | makakilo city
# Processing Record 49 of Set 5 | lata
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 6 | zaria
# Processing Record 2 of Set 6 | banjar
# Processing Record 3 of Set 6 | opuwo
# Processing Record 4 of Set 6 | svetlyy
# Processing Record 5 of Set 6 | kailua
# Processing Record 6 of Set 6 | katsuura
# Processing Record 7 of Set 6 | samarai
# Processing Record 8 of Set 6 | peoria
# Processing Record 9 of Set 6 | cayenne
# Processing Record 10 of Set 6 | gat
# Processing Record 11 of Set 6 | palmer
# Processing Record 12 of Set 6 | olafsvik
# Processing Record 13 of Set 6 | soledade
# Processing Record 14 of Set 6 | broome
# Processing Record 15 of Set 6 | roebourne
# Processing Record 16 of Set 6 | mecca
# Processing Record 17 of Set 6 | chokurdakh
# Processing Record 18 of Set 6 | moron
# Processing Record 19 of Set 6 | buedu
# Processing Record 20 of Set 6 | labuhan
# Processing Record 21 of Set 6 | rudnogorsk
# Processing Record 22 of Set 6 | donegal
# Processing Record 23 of Set 6 | contamana
# Processing Record 24 of Set 6 | azul
# Processing Record 25 of Set 6 | fuxin
# Processing Record 26 of Set 6 | kaitangata
# Processing Record 27 of Set 6 | kyra
# Processing Record 28 of Set 6 | seda
# Processing Record 29 of Set 6 | gigmoto
# Processing Record 30 of Set 6 | mursalimkino
# Processing Record 31 of Set 6 | novaya zaimka
# Processing Record 32 of Set 6 | nome
# Processing Record 33 of Set 6 | vung tau
# Processing Record 34 of Set 6 | muisne
# Processing Record 35 of Set 6 | scarborough
# Processing Record 36 of Set 6 | mombetsu
# Processing Record 37 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 6 | hirna
# Processing Record 39 of Set 6 | rantepao
# Processing Record 40 of Set 6 | necochea
# Processing Record 41 of Set 6 | karratha
# Processing Record 42 of Set 6 | puerto del rosario
# Processing Record 43 of Set 6 | pengcheng
# Processing Record 44 of Set 6 | nyrob
# Processing Record 45 of Set 6 | pavlovka
# Processing Record 46 of Set 6 | iguape
# Processing Record 47 of Set 6 | peleduy
# Processing Record 48 of Set 6 | manokwari
# Processing Record 49 of Set 6 | carnarvon
# Processing Record 50 of Set 6 | kodiak
# Processing Record 1 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 7 | piopio
# Processing Record 3 of Set 7 | petawawa
# Processing Record 4 of Set 7 | kampot
# Processing Record 5 of Set 7 | trelew
# Processing Record 6 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 7 | rio gallegos
# Processing Record 8 of Set 7 | mariental
# Processing Record 9 of Set 7 | skibbereen
# Processing Record 10 of Set 7 | kot kapura
# Processing Record 11 of Set 7 | la ronge
# Processing Record 12 of Set 7 | poum
# Processing Record 13 of Set 7 | snyder
# Processing Record 14 of Set 7 | bridlington
# Processing Record 15 of Set 7 | port-gentil
# Processing Record 16 of Set 7 | salinopolis
# Processing Record 17 of Set 7 | cairns
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | fare
# Processing Record 20 of Set 7 | solnechnyy
# Processing Record 21 of Set 7 | madingou
# Processing Record 22 of Set 7 | lakes entrance
# Processing Record 23 of Set 7 | buta
# Processing Record 24 of Set 7 | brae
# Processing Record 25 of Set 7 | salekhard
# Processing Record 26 of Set 7 | nouadhibou
# Processing Record 27 of Set 7 | beringovskiy
# Processing Record 28 of Set 7 | antofagasta
# Processing Record 29 of Set 7 | bucerias
# Processing Record 30 of Set 7 | tawnat
# City not found. Skipping...
# Processing Record 31 of Set 7 | la ferte-bernard
# Processing Record 32 of Set 7 | ayame
# Processing Record 33 of Set 7 | slonim
# Processing Record 34 of Set 7 | mount gambier
# Processing Record 35 of Set 7 | faya
# Processing Record 36 of Set 7 | kahului
# Processing Record 37 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 38 of Set 7 | insar
# Processing Record 39 of Set 7 | sydney mines
# Processing Record 40 of Set 7 | wajima
# Processing Record 41 of Set 7 | freeport
# Processing Record 42 of Set 7 | kaeo
# Processing Record 43 of Set 7 | labuan
# Processing Record 44 of Set 7 | nabire
# Processing Record 45 of Set 7 | kathu
# Processing Record 46 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 7 | ulaangom
# Processing Record 48 of Set 7 | mayo
# Processing Record 49 of Set 7 | mednogorskiy
# Processing Record 50 of Set 7 | yaritagua
# Processing Record 1 of Set 8 | dunedin
# Processing Record 2 of Set 8 | vilyuysk
# Processing Record 3 of Set 8 | caraballeda
# Processing Record 4 of Set 8 | jackson
# Processing Record 5 of Set 8 | katiola
# Processing Record 6 of Set 8 | mankera
# Processing Record 7 of Set 8 | san patricio
# Processing Record 8 of Set 8 | teya
# Processing Record 9 of Set 8 | terrace bay
# Processing Record 10 of Set 8 | takoradi
# Processing Record 11 of Set 8 | ponta do sol
# Processing Record 12 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 8 | siniscola
# Processing Record 14 of Set 8 | dhidhdhoo
# Processing Record 15 of Set 8 | betioky
# Processing Record 16 of Set 8 | alyangula
# Processing Record 17 of Set 8 | kandrian
# Processing Record 18 of Set 8 | ankang
# Processing Record 19 of Set 8 | estelle
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | besikduzu
# Processing Record 22 of Set 8 | oyama
# Processing Record 23 of Set 8 | sidmouth
# Processing Record 24 of Set 8 | laranjeiras do sul
# Processing Record 25 of Set 8 | tongren
# Processing Record 26 of Set 8 | naze
# Processing Record 27 of Set 8 | sisimiut
# Processing Record 28 of Set 8 | pascagoula
# Processing Record 29 of Set 8 | verdalsora
# City not found. Skipping...
# Processing Record 30 of Set 8 | ishigaki
# Processing Record 31 of Set 8 | ostersund
# Processing Record 32 of Set 8 | kieta
# Processing Record 33 of Set 8 | eucaliptus
# Processing Record 34 of Set 8 | alekseyevskaya
# Processing Record 35 of Set 8 | rock sound
# Processing Record 36 of Set 8 | marsa matruh
# Processing Record 37 of Set 8 | pahrump
# Processing Record 38 of Set 8 | kearney
# Processing Record 39 of Set 8 | slevik
# City not found. Skipping...
# Processing Record 40 of Set 8 | itarema
# Processing Record 41 of Set 8 | hurghada
# Processing Record 42 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 43 of Set 8 | touho
# Processing Record 44 of Set 8 | warmbad
# Processing Record 45 of Set 8 | huarmey
# Processing Record 46 of Set 8 | along
# Processing Record 47 of Set 8 | newport
# Processing Record 48 of Set 8 | tarakan
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 1 of Set 9 | saldanha
# Processing Record 2 of Set 9 | amapa
# Processing Record 3 of Set 9 | hambantota
# Processing Record 4 of Set 9 | port moresby
# Processing Record 5 of Set 9 | mastic beach
# Processing Record 6 of Set 9 | the pas
# Processing Record 7 of Set 9 | inta
# Processing Record 8 of Set 9 | harper
# Processing Record 9 of Set 9 | inuvik
# Processing Record 10 of Set 9 | kedrovyy
# Processing Record 11 of Set 9 | coos bay
# Processing Record 12 of Set 9 | havre
# Processing Record 13 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 14 of Set 9 | tando ghulam ali
# Processing Record 15 of Set 9 | gravelbourg
# Processing Record 16 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 9 | oriximina
# Processing Record 18 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 9 | williamsburg
# Processing Record 20 of Set 9 | buritis
# Processing Record 21 of Set 9 | tigzirt
# Processing Record 22 of Set 9 | kondinskoye
# Processing Record 23 of Set 9 | tuzha
# Processing Record 24 of Set 9 | richards bay
# Processing Record 25 of Set 9 | kozhva
# Processing Record 26 of Set 9 | kaberamaido
# Processing Record 27 of Set 9 | obodivka
# Processing Record 28 of Set 9 | sorong
# Processing Record 29 of Set 9 | ulladulla
# Processing Record 30 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 9 | nhulunbuy
# Processing Record 32 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 33 of Set 9 | cootamundra
# Processing Record 34 of Set 9 | nishihara
# Processing Record 35 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 36 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 9 | haines junction
# Processing Record 39 of Set 9 | ardesen
# Processing Record 40 of Set 9 | vao
# Processing Record 41 of Set 9 | korla
# Processing Record 42 of Set 9 | kajaani
# Processing Record 43 of Set 9 | caravelas
# Processing Record 44 of Set 9 | oloron-sainte-marie
# Processing Record 45 of Set 9 | pokhara
# Processing Record 46 of Set 9 | slobozia
# Processing Record 47 of Set 9 | sovetskiy
# Processing Record 48 of Set 9 | nadym
# Processing Record 49 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 10 | dancheng
# Processing Record 2 of Set 10 | ilulissat
# Processing Record 3 of Set 10 | lompoc
# Processing Record 4 of Set 10 | nouna
# Processing Record 5 of Set 10 | klaksvik
# Processing Record 6 of Set 10 | oistins
# Processing Record 7 of Set 10 | zhuhai
# Processing Record 8 of Set 10 | bathsheba
# Processing Record 9 of Set 10 | jacqueville
# Processing Record 10 of Set 10 | airai
# Processing Record 11 of Set 10 | northam
# Processing Record 12 of Set 10 | bella union
# Processing Record 13 of Set 10 | tingi
# Processing Record 14 of Set 10 | turukhansk
# Processing Record 15 of Set 10 | college
# Processing Record 16 of Set 10 | tromso
# Processing Record 17 of Set 10 | luderitz
# Processing Record 18 of Set 10 | kennebunk
# Processing Record 19 of Set 10 | chara
# Processing Record 20 of Set 10 | moose factory
# Processing Record 21 of Set 10 | tuatapere
# Processing Record 22 of Set 10 | abancay
# Processing Record 23 of Set 10 | rio grande
# Processing Record 24 of Set 10 | banikoara
# Processing Record 25 of Set 10 | codajas
# Processing Record 26 of Set 10 | ponta delgada
# Processing Record 27 of Set 10 | aizawl
# Processing Record 28 of Set 10 | sabzevar
# Processing Record 29 of Set 10 | barzas
# Processing Record 30 of Set 10 | zhangjiakou
# Processing Record 31 of Set 10 | samarkand
# Processing Record 32 of Set 10 | imeni poliny osipenko
# Processing Record 33 of Set 10 | pevek
# Processing Record 34 of Set 10 | husavik
# Processing Record 35 of Set 10 | aksarka
# Processing Record 36 of Set 10 | aleksandrov gay
# Processing Record 37 of Set 10 | bayir
# Processing Record 38 of Set 10 | yulara
# Processing Record 39 of Set 10 | trairi
# Processing Record 40 of Set 10 | barra
# Processing Record 41 of Set 10 | honiara
# Processing Record 42 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 43 of Set 10 | komsomolskiy
# Processing Record 44 of Set 10 | tignere
# Processing Record 45 of Set 10 | torbat-e jam
# Processing Record 46 of Set 10 | rivadavia
# Processing Record 47 of Set 10 | miandoab
# Processing Record 48 of Set 10 | adwa
# Processing Record 49 of Set 10 | dingle
# Processing Record 50 of Set 10 | vitim
# Processing Record 1 of Set 11 | egvekinot
# Processing Record 2 of Set 11 | sendhwa
# Processing Record 3 of Set 11 | sosva
# Processing Record 4 of Set 11 | tekeli
# Processing Record 5 of Set 11 | yarada
# Processing Record 6 of Set 11 | ampanihy
# Processing Record 7 of Set 11 | cilegon
# Processing Record 8 of Set 11 | ponnani
# Processing Record 9 of Set 11 | kruisfontein
# Processing Record 10 of Set 11 | codrington
# Processing Record 11 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 11 | tynda
# Processing Record 13 of Set 11 | niquero
# Processing Record 14 of Set 11 | harindanga
# Processing Record 15 of Set 11 | comodoro rivadavia
# Processing Record 16 of Set 11 | luanda
# Processing Record 17 of Set 11 | lagoa
# Processing Record 18 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 19 of Set 11 | ayan
# Processing Record 20 of Set 11 | krasnoselkup
# Processing Record 21 of Set 11 | kemijarvi
# Processing Record 22 of Set 11 | barra do garcas
# Processing Record 23 of Set 11 | angoche
# Processing Record 24 of Set 11 | springbok
# Processing Record 25 of Set 11 | ola
# Processing Record 26 of Set 11 | lucapa
# Processing Record 27 of Set 11 | ajdabiya
# Processing Record 28 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 11 | boyolangu
# Processing Record 30 of Set 11 | arlit
# Processing Record 31 of Set 11 | avera
# Processing Record 32 of Set 11 | srandakan
# Processing Record 33 of Set 11 | lasa
# Processing Record 34 of Set 11 | north bend
# Processing Record 35 of Set 11 | forestville
# Processing Record 36 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 11 | pandan niog
# Processing Record 38 of Set 11 | vila franca do campo
# Processing Record 39 of Set 11 | leeton
# Processing Record 40 of Set 11 | luwuk
# Processing Record 41 of Set 11 | whitianga
# Processing Record 42 of Set 11 | olinda
# Processing Record 43 of Set 11 | moerai
# Processing Record 44 of Set 11 | kavieng
# Processing Record 45 of Set 11 | salina cruz
# Processing Record 46 of Set 11 | kyren
# Processing Record 47 of Set 11 | souillac
# Processing Record 48 of Set 11 | moroni
# Processing Record 49 of Set 11 | itoman
# Processing Record 50 of Set 11 | vossevangen
# Processing Record 1 of Set 12 | tessalit
# Processing Record 2 of Set 12 | remedios
# Processing Record 3 of Set 12 | maniitsoq
# Processing Record 4 of Set 12 | trezzano sul naviglio
# Processing Record 5 of Set 12 | port hedland
# Processing Record 6 of Set 12 | saint-pierre
# Processing Record 7 of Set 12 | umm bab
# Processing Record 8 of Set 12 | tuy hoa
# Processing Record 9 of Set 12 | chai badan
# Processing Record 10 of Set 12 | patiya
# Processing Record 11 of Set 12 | ovsyanka
# Processing Record 12 of Set 12 | walvis bay
# Processing Record 13 of Set 12 | boa vista
# Processing Record 14 of Set 12 | homer
# Processing Record 15 of Set 12 | atar
# Processing Record 16 of Set 12 | nova vodolaha
# Processing Record 17 of Set 12 | gogrial
# Processing Record 18 of Set 12 | tianpeng
# Processing Record 19 of Set 12 | yeppoon
# Processing Record 20 of Set 12 | west wendover
# Processing Record 21 of Set 12 | la palma
# Processing Record 22 of Set 12 | novo aripuana
# Processing Record 23 of Set 12 | oromocto
# Processing Record 24 of Set 12 | sangar
# Processing Record 25 of Set 12 | moussoro
# Processing Record 26 of Set 12 | auki
# Processing Record 27 of Set 12 | los naranjos
# Processing Record 28 of Set 12 | elmadag
# Processing Record 29 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 12 | alice springs
# Processing Record 31 of Set 12 | asau
# Processing Record 32 of Set 12 | talnakh
# Processing Record 33 of Set 12 | ca mau
# Processing Record 34 of Set 12 | zhigansk
# Processing Record 35 of Set 12 | agadez
# Processing Record 36 of Set 12 | tarija
# Processing Record 37 of Set 12 | alta floresta
# Processing Record 38 of Set 12 | taiobeiras
# Processing Record 39 of Set 12 | aksu
# Processing Record 40 of Set 12 | blagoyevo
# Processing Record 41 of Set 12 | road town
# Processing Record 42 of Set 12 | pervomayskaya
# Processing Record 43 of Set 12 | ende
# Processing Record 44 of Set 12 | broken hill
# Processing Record 45 of Set 12 | mendeleyevo
# Processing Record 46 of Set 12 | cucutilla
# Processing Record 47 of Set 12 | atascocita
# Processing Record 48 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 12 | sinnamary
# Processing Record 50 of Set 12 | van buren
# Processing Record 1 of Set 13 | machico
# Processing Record 2 of Set 13 | tahoua
# Processing Record 3 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 4 of Set 13 | lloydminster
# Processing Record 5 of Set 13 | henties bay
# Processing Record 6 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 13 | mairana
# Processing Record 8 of Set 13 | omis
# Processing Record 9 of Set 13 | dogondoutchi
# Processing Record 10 of Set 13 | puerto leguizamo
# Processing Record 11 of Set 13 | mahanoro
# Processing Record 12 of Set 13 | beatrice
# Processing Record 13 of Set 13 | ondjiva
# Processing Record 14 of Set 13 | takab
# Processing Record 15 of Set 13 | baherden
# Processing Record 16 of Set 13 | meulaboh
# Processing Record 17 of Set 13 | ust-nera
# Processing Record 18 of Set 13 | indianola
# Processing Record 19 of Set 13 | el cairo
# Processing Record 20 of Set 13 | hervey bay
# Processing Record 21 of Set 13 | sarahan
# City not found. Skipping...
# Processing Record 22 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 13 | shihezi
# Processing Record 24 of Set 13 | moletai
# Processing Record 25 of Set 13 | paracuru
# Processing Record 26 of Set 13 | pacific grove
# Processing Record 27 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 28 of Set 13 | cascais
# Processing Record 29 of Set 13 | edson
# Processing Record 30 of Set 13 | okoneshnikovo
# Processing Record 31 of Set 13 | garowe
# Processing Record 32 of Set 13 | shingu
# Processing Record 33 of Set 13 | bodo
# Processing Record 34 of Set 13 | mattru
# Processing Record 35 of Set 13 | santa cruz
# Processing Record 36 of Set 13 | pangkalanbuun
# Processing Record 37 of Set 13 | fortuna
# Processing Record 38 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 13 | ginda
# Processing Record 40 of Set 13 | ahuimanu
# Processing Record 41 of Set 13 | nanga eboko
# Processing Record 42 of Set 13 | atambua
# Processing Record 43 of Set 13 | pyay
# Processing Record 44 of Set 13 | damara
# Processing Record 45 of Set 13 | filingue
# Processing Record 46 of Set 13 | mlonggo
# Processing Record 47 of Set 13 | beloha
# Processing Record 48 of Set 13 | maarianhamina
# Processing Record 49 of Set 13 | deputatskiy
# Processing Record 50 of Set 13 | rocha
# Processing Record 1 of Set 14 | mount isa
# Processing Record 2 of Set 14 | forbes
# Processing Record 3 of Set 14 | muli
# Processing Record 4 of Set 14 | ust-tarka
# Processing Record 5 of Set 14 | adre
# Processing Record 6 of Set 14 | galeana
# Processing Record 7 of Set 14 | acapulco
# Processing Record 8 of Set 14 | shache
# Processing Record 9 of Set 14 | marawi
# Processing Record 10 of Set 14 | esfarayen
# Processing Record 11 of Set 14 | kanchanaburi
# Processing Record 12 of Set 14 | port-cartier
# Processing Record 13 of Set 14 | oranjemund
# Processing Record 14 of Set 14 | mandali
# Processing Record 15 of Set 14 | fairbanks
# Processing Record 16 of Set 14 | ovalle
# Processing Record 17 of Set 14 | quelimane
# Processing Record 18 of Set 14 | tiznit
# Processing Record 19 of Set 14 | saint pete beach
# Processing Record 20 of Set 14 | zhezkazgan
# Processing Record 21 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 22 of Set 14 | teguise
# Processing Record 23 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 24 of Set 14 | marystown
# Processing Record 25 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 14 | kaniama
# Processing Record 27 of Set 14 | waingapu
# Processing Record 28 of Set 14 | ha tinh
# Processing Record 29 of Set 14 | hualmay
# Processing Record 30 of Set 14 | toora-khem
# Processing Record 31 of Set 14 | vila
# Processing Record 32 of Set 14 | namibe
# Processing Record 33 of Set 14 | mahibadhoo
# Processing Record 34 of Set 14 | dabaca
# Processing Record 35 of Set 14 | inhambane
# Processing Record 36 of Set 14 | minbu
# Processing Record 37 of Set 14 | kultayevo
# Processing Record 38 of Set 14 | otradinskiy
# City not found. Skipping...
# Processing Record 39 of Set 14 | namatanai
# Processing Record 40 of Set 14 | charagua
# Processing Record 41 of Set 14 | butajira
# Processing Record 42 of Set 14 | gaoua
# Processing Record 43 of Set 14 | kovur
# Processing Record 44 of Set 14 | mogochin
# City not found. Skipping...
# Processing Record 45 of Set 14 | vaitape
# Processing Record 46 of Set 14 | bud
# Processing Record 47 of Set 14 | praia da vitoria
# Processing Record 48 of Set 14 | simao
# Processing Record 49 of Set 14 | howard springs
# Processing Record 50 of Set 14 | qui nhon
# Processing Record 1 of Set 15 | paamiut
# Processing Record 2 of Set 15 | rincon
# Processing Record 3 of Set 15 | cockburn town
# Processing Record 4 of Set 15 | evanston
# Processing Record 5 of Set 15 | independence
# Processing Record 6 of Set 15 | shahr-e babak
# Processing Record 7 of Set 15 | tanete
# Processing Record 8 of Set 15 | mingaora
# Processing Record 9 of Set 15 | amherst center
# Processing Record 10 of Set 15 | erenhot
# Processing Record 11 of Set 15 | amursk
# Processing Record 12 of Set 15 | buraydah
# Processing Record 13 of Set 15 | jutiapa
# Processing Record 14 of Set 15 | houma
# Processing Record 15 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 15 | hobyo
# Processing Record 17 of Set 15 | yerbogachen
# Processing Record 18 of Set 15 | fereydun kenar
# Processing Record 19 of Set 15 | shadrinsk
# Processing Record 20 of Set 15 | agnibilekrou
# Processing Record 21 of Set 15 | alexander city
# Processing Record 22 of Set 15 | pionerskiy
# Processing Record 23 of Set 15 | fukue
# Processing Record 24 of Set 15 | kashi
# Processing Record 25 of Set 15 | tabora
# Processing Record 26 of Set 15 | guerrero negro
# Processing Record 27 of Set 15 | kushima
# Processing Record 28 of Set 15 | padang
# Processing Record 29 of Set 15 | batagay-alyta
# Processing Record 30 of Set 15 | karatau
# Processing Record 31 of Set 15 | aguie
# Processing Record 32 of Set 15 | coulihaut
# City not found. Skipping...
# Processing Record 33 of Set 15 | valenca
# Processing Record 34 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 15 | roswell
# Processing Record 36 of Set 15 | hami
# Processing Record 37 of Set 15 | abha
# Processing Record 38 of Set 15 | foumban
# Processing Record 39 of Set 15 | alexandria
# Processing Record 40 of Set 15 | kamaishi
# Processing Record 41 of Set 15 | antalaha
# Processing Record 42 of Set 15 | ashqelon
# Processing Record 43 of Set 15 | prince rupert
# Processing Record 44 of Set 15 | evensk
# Processing Record 45 of Set 15 | eyl
# Processing Record 46 of Set 15 | lethem
# Processing Record 47 of Set 15 | stornoway
# Processing Record 48 of Set 15 | dakar
# Processing Record 49 of Set 15 | dargaville
# Processing Record 50 of Set 15 | chimbote
# Processing Record 1 of Set 16 | akdepe
# Processing Record 2 of Set 16 | flin flon
# Processing Record 3 of Set 16 | ancud
# Processing Record 4 of Set 16 | arman
# Processing Record 5 of Set 16 | morondava
# Processing Record 6 of Set 16 | whitehorse
# Processing Record 7 of Set 16 | lalmohan
# Processing Record 8 of Set 16 | smolenka
# Processing Record 9 of Set 16 | kachikau
# City not found. Skipping...
# Processing Record 10 of Set 16 | yinchuan
# Processing Record 11 of Set 16 | ayios nikolaos
# Processing Record 12 of Set 16 | kenai
# Processing Record 13 of Set 16 | albenga
# Processing Record 14 of Set 16 | jieshi
# Processing Record 15 of Set 16 | aksha
# Processing Record 16 of Set 16 | camacha
# Processing Record 17 of Set 16 | kindu
# Processing Record 18 of Set 16 | chenzhou
# Processing Record 19 of Set 16 | kloulklubed
# Processing Record 20 of Set 16 | tual
# Processing Record 21 of Set 16 | tabukiniberu
# City not found. Skipping...
# Processing Record 22 of Set 16 | kitimat
# Processing Record 23 of Set 16 | westport
# Processing Record 24 of Set 16 | bardiyah
# Processing Record 25 of Set 16 | taperoa
# Processing Record 26 of Set 16 | houston
# Processing Record 27 of Set 16 | ayorou
# Processing Record 28 of Set 16 | boyuibe
# Processing Record 29 of Set 16 | sabha
# Processing Record 30 of Set 16 | prainha
# Processing Record 31 of Set 16 | tupik
# Processing Record 32 of Set 16 | ust-ordynskiy
# Processing Record 33 of Set 16 | iisalmi
# Processing Record 34 of Set 16 | puerto escondido
# Processing Record 35 of Set 16 | bonthe
# Processing Record 36 of Set 16 | baculin
# Processing Record 37 of Set 16 | xinxiang
# Processing Record 38 of Set 16 | bilibino
# Processing Record 39 of Set 16 | linhares
# Processing Record 40 of Set 16 | limbang
# Processing Record 41 of Set 16 | gryazovets
# Processing Record 42 of Set 16 | myitkyina
# Processing Record 43 of Set 16 | kropotkin
# Processing Record 44 of Set 16 | bilma
# Processing Record 45 of Set 16 | patti
# Processing Record 46 of Set 16 | mpika
# Processing Record 47 of Set 16 | cerritos
# Processing Record 48 of Set 16 | felsopakony
# Processing Record 49 of Set 16 | macusani
# Processing Record 50 of Set 16 | rawson
# Processing Record 1 of Set 17 | fort nelson
# Processing Record 2 of Set 17 | jiangyou
# Processing Record 3 of Set 17 | flinders
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas -53.1500  -70.9167     57.20        41           0
# 1         Smithers  54.7804 -127.1743     23.00        80          90
# 2       Nikolskoye  59.7035   30.7861     14.00        92          90
# 3         Carauari  -4.8828  -66.8958     80.22        80          41
# 4         La Rioja  42.2500   -2.5000     46.40        87          40
# 5  Agustin Codazzi  10.0341  -73.2361     91.60        36           6
# 6          Ibirite -20.0219  -44.0589     80.60        34           0
# 7           Baykit  61.6700   96.3700    -36.49        75          95
# 8          Qaanaaq  77.4840  -69.3632     11.26        89          84
# 9           Lardos  36.0942   28.0157     55.40        76          40
#
#    Wind Speed Country                 Date Current Description
# 0       29.93      CL  2021-01-21 22:14:37           clear sky
# 1        4.61      CA  2021-01-21 22:14:37     overcast clouds
# 2       13.42      RU  2021-01-21 22:14:37                snow
# 3        2.64      BR  2021-01-21 22:14:37          light rain
# 4        2.30      ES  2021-01-21 22:14:37    scattered clouds
# 5        5.01      CO  2021-01-21 22:14:37           clear sky
# 6       12.66      BR  2021-01-21 22:14:37           clear sky
# 7        3.58      RU  2021-01-21 22:14:37     overcast clouds
# 8        2.73      GL  2021-01-21 22:14:37       broken clouds
# 9        6.91      GR  2021-01-21 22:14:38          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
